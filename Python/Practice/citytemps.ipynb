# %% [markdown]
# ## MATPLOT

# %% [markdown]
# ### Import Library
#
# **import matplotlib.pyplot as plt**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Line Chart**
#
# (Line charts show progression over time)
#
# **A. Plotting Dots on Chart**
#
#     x=[1,4,6]
#     y=[5,2,7]
#
#
# **B. Displaying Lines on Chart**
#
#     plt.plot(x,y)
#
#
# **C. Display Labels on X and Y axis**
#
#     plt.xlabel('X Label')
#     plt.ylabel('Y Label')
#
#
# **D. Display a Title**
#
#     plt.title('Title')
#
#
# **E. Display Chart**
#
#     plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Day = ['Monday', 'Tuesday','Wednesday','Thursday', 'Friday','Saturday','Sunday']
Temperature = [63,78,90,65,46,74,88]

plt.plot(Day, Temperature)

plt.xlabel ('Day')
plt.ylabel ('Temp (F)')

plt.title ('Weekly Temperature')
plt.show()

# %% [markdown]
# ## **Multiple Line Chart**
#
# (Comparing progression of two or more datasets)
#
# ****
#     x= [1,2,3]
#     y= [3,4,5]
#
#     x1=[2,3,5]
#     y1=[4,5,6]
#
#     x2=[0,2,6]
#     y2=[10,23,5]
#
#
# **A. Display the dots on a line chart**
#
#     plt.plot (x, y)
#     plt.plot (x1,y1)
#     plt.plot (x2,y2)
#
# **B. Display Titles**
#
#     plt.title ('title')
#     plt.title ('title 1')
#     plt.title ('title 2')
#
# **C.Another options : (simplify)**
#
#     plt.plot(x,y,label = 'label')
#     plt.plot(x1,y1,label1 ='label 1')
#     plt.plot(x2,y2, label2 = 'label 2')
#
#
# **D. Display Chart**
#
#     plt.s1. how()

# %%
import matplotlib.pyplot as plt

# %%
Month = ['Jan','Feb','Mar','April','May', 'June']

Temp_NY=[34,55,42,44,78,55]
Temp_Chi = [21,42,53,56,92,22]
Temp_Mia= [102, 68, 97,34,52,44]

# %%
plt.plot(Month, Temp_NY, label = 'New York')
plt.plot(Month, Temp_Chi,label = 'Chicago')
plt.plot(Month, Temp_Mia,label = 'Miami')


plt.xlabel('Month')
plt.ylabel('Temp')
plt.title('City Temp')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

Month = ['Jan', 'Feb', 'Mar', 'April', 'May', 'June']

Temp_NY = [34, 55, 42, 44, 78, 55]
Temp_Chi = [21, 42, 53, 56, 92, 22]
Temp_Mia = [102, 68, 97, 34, 52, 44]

# Plotting the data
plt.plot(Month, Temp_NY, label='New York')
plt.plot(Month, Temp_Chi, label='Chicago')
plt.plot(Month, Temp_Mia, label='Miami')

# Adding labels and title
plt.xlabel('Month')
plt.ylabel('Temperature (°F)')
plt.title('City Temperatures')
plt.legend()

# Show the plot
plt.show()
